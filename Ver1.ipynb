# %%
from wifi import Cell, Scheme

# %%
# Replace 'wlan0' with your wireless device ID
cells = list(Cell.all('wlan0'))
for cell in cells:
    print(f"SSID: {cell.ssid}, Signal Strength: {cell.signal} dBm")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Replace 'wlan0' with your wireless device ID
# ----> 2 cells = list(Cell.all('wlan0'))
#       3 for cell in cells:
#       4     print(f"SSID: {cell.ssid}, Signal Strength: {cell.signal} dBm")
#
# File c:\Mine\Python\Lib\site-packages\wifi\scan.py:38, in Cell.all(cls, interface)
#      34 """
#      35 Returns a list of all cells extracted from the output of iwlist.
#      36 """
#      37 try:
# ---> 38     iwlist_scan = subprocess.check_output(['/sbin/iwlist', interface, 'scan'],
#      39                                           stderr=subprocess.STDOUT)
#      40 except subprocess.CalledProcessError as e:
#      41     raise InterfaceError(e.output.strip())
#
# File c:\Mine\Python\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
# ...
